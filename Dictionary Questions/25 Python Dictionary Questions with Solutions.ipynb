# %% [markdown]
# <h1 style="color:blue" align="center">Python Dictionary Questions</h1>

# %% [markdown]
# 25 Python Dictionary Coding Questions along with Explanations for each. Let's get started ↓
#
# **Question 1:**
# Create an empty dictionary.
#
# **Solution:**
# ```python
# my_dict = {}
# ```
#
# **Question 2:**
# Create a dictionary with key-value pairs for a person's name and age.
#
# **Solution:**
# ```python
# person = {"name": "John", "age": 30}
# ```
#
# **Question 3:**
# Access the value associated with the key "age" in the `person` dictionary.
#
# **Solution:**
# ```python
# age = person["age"]
# ```
#
# **Question 4:**
# Check if a key exists in the `person` dictionary.
#
# **Solution:**
# ```python
# if "name" in person:
#     print("Key 'name' exists.")
# ```
#
# **Question 5:**
# Add a new key-value pair "city" with the value "New York" to the `person` dictionary.
#
# **Solution:**
# ```python
# person["city"] = "New York"
# ```
#
# **Question 6:**
# Remove the key-value pair with the key "age" from the `person` dictionary.
#
# **Solution:**
# ```python
# del person["age"]
# ```
#
# **Question 7:**
# Iterate through the keys in the `person` dictionary.
#
# **Solution:**
# ```python
# for key in person:
#     print(key)
# ```
#
# **Question 8:**
# Iterate through the values in the `person` dictionary.
#
# **Solution:**
# ```python
# for value in person.values():
#     print(value)
# ```
#
# **Question 9:**
# Iterate through both keys and values in the `person` dictionary.
#
# **Solution:**
# ```python
# for key, value in person.items():
#     print(key, value)
# ```
#
# **Question 10:**
# Create a dictionary with default values using the `dict.fromkeys()` method.
#
# **Solution:**
# ```python
# defaults = dict.fromkeys(["name", "age", "city"], "Unknown")
# ```
#
# **Question 11:**
# Get the value associated with a key using the `dict.get()` method with a default value.
#
# **Solution:**
# ```python
# age = person.get("age", 0)
# ```
#
# **Question 12:**
# Count the number of occurrences of each character in a string using a dictionary.
#
# **Solution:**
# ```python
# text = "hello"
# char_count = {}
# for char in text:
#     char_count[char] = char_count.get(char, 0) + 1
# ```
#
# **Question 13:**
# Merge two dictionaries.
#
# **Solution:**
# ```python
# dict1 = {"a": 1, "b": 2}
# dict2 = {"b": 3, "c": 4}
# merged_dict = {**dict1, **dict2}
# ```
#
# **Question 14:**
# Create a dictionary where the values are squares of the keys.
#
# **Solution:**
# ```python
# squares = {x: x**2 for x in range(1, 6)}
# ```
#
# **Question 15:**
# Find the key with the maximum value in a dictionary.
#
# **Solution:**
# ```python
# max_key = max(person, key=person.get)
# ```
#
# **Question 16:**
# Sort a dictionary by its keys.
#
# **Solution:**
# ```python
# sorted_dict = dict(sorted(person.items()))
# ```
#
# **Question 17:**
# Check if two dictionaries are equal.
#
# **Solution:**
# ```python
# if dict1 == dict2:
#     print("Dictionaries are equal.")
# ```
#
# **Question 18:**
# Remove all elements from a dictionary.
#
# **Solution:**
# ```python
# person.clear()
# ```
#
# **Question 19:**
# Create a nested dictionary.
#
# **Solution:**
# ```python
# nested_dict = {"first": {"a": 1, "b": 2}, "second": {"c": 3, "d": 4}}
# ```
#
# **Question 20:**
# Get a list of all keys in a dictionary.
#
# **Solution:**
# ```python
# keys_list = list(person.keys())
# ```
#
# **Question 21:**
# Get a list of all values in a dictionary.
#
# **Solution:**
# ```python
# values_list = list(person.values())
# ```
#
# **Question 22:**
# Update values in a dictionary using another dictionary.
#
# **Solution:**
# ```python
# new_data = {"age": 31, "city": "Los Angeles"}
# person.update(new_data)
# ```
#
# **Question 23:**
# Remove a key from a dictionary using the `pop()` method.
#
# **Solution:**
# ```python
# removed_value = person.pop("city", "Default City")
# ```
#
# **Question 24:**
# Get a list of tuples containing key-value pairs from a dictionary.
#
# **Solution:**
# ```python
# items_list = list(person.items())
# ```
#
# **Question 25:**
# Convert a list of tuples into a dictionary.
#
# **Solution:**
# ```python
# tuple_list = [("a", 1), ("b", 2), ("c", 3)]
# converted_dict = dict(tuple_list)
# ```
